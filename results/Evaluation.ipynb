# %% [markdown]
# # Model evaluation
#
# In this notebook, the transformer-based models analyzed in this work are evaluated according to their tumor morphology mentions detection performance achieved in the Cantemist-NER task (on the test corpus).

# %%
import tensorflow as tf

# Auxiliary components
import sys
sys.path.append("../")
from nlp_utils import *

# Hyper-parameters
text_col = "raw_text"

# %% [markdown]
# ## Load text

# %%
corpus_path = "../datasets/cantemist_v6/"
sub_task_path = "cantemist-ner/"

# %% [markdown]
# ### Test corpus

# %%
# %%time
test_path = corpus_path + "test-set/" + sub_task_path
test_files = [f for f in os.listdir(test_path) if os.path.isfile(test_path + f) and f.split('.')[-1] == 'txt']
test_data = load_text_files(test_files, test_path)
df_text_test = pd.DataFrame({'doc_id': [s.split('.txt')[0] for s in test_files], 'raw_text': test_data})
# Out:
# CPU times: user 8.14 ms, sys: 40 µs, total: 8.18 ms
# Wall time: 7.97 ms

# %%
df_text_test.shape
# Out:
# (300, 2)

# %%
df_text_test.head()
# Out:
#         doc_id                                           raw_text
# 0   cc_onco877  Anamnesis\nMujer de 59 años, alérgica a penici...
# 1  cc_onco1075  Anamnesis\nMujer de 52 años, sin alergias cono...
# 2  cc_onco1450  Anamnesis\nMujer de 51 años de edad, sin antec...
# 3  cc_onco1165  Anamnesis\nPaciente varón de 75 años sin hábit...
# 4  cc_onco1298  Anamnesis\nMujer de 60 años, exfumadora de 20 ...

# %%
len(set(df_text_test['doc_id']))
# Out:
# 300

# %%
df_text_test.raw_text[0]
# Out:
# 'Anamnesis\nMujer de 59 años, alérgica a penicilina y procaína. Fumadora activa (IPA: 43).\nAntecedentes familiares: abuelo materno diagnosticado de carcinoma colon a los 70 años; madre diagnosticada de carcinoma de mama bilateral a los 50 años; padre fallecido de carcinoma gástrico a los 47 años; tres tías maternas diagnosticadas de carcinoma de mama a los 55, 56 y 57 años respectivamente; y tres primas afectas de cáncer de mama.\nAntecedentes personales: bronquitis crónica, poliposis colónica, carcinoma ductal infiltrante clásico mama pT2pN0M0 G2 subtipo tumoral luminal a (RH: +, HER-2: negativo) intervenido en agosto de 2013 mediante tumorectomía mama izquierda (patrón round block) + biopsia selectiva ganglio centinela (negativo) y posterior QT adyuvante con esquema TC (paclitaxel-ciclofosfamida) x 4 ciclos.\nAcude en noviembre de 2013 a visita de seguimiento tras finalizar tratamiento adyuvante. Asintomática.\n\nExploración física\nTemperatura axilar 36,5ºC, tensión arterial 130/83 mm Hg, frecuencia cardiaca 90 lpm y saturación basal de oxígeno del 98 %.\nConsciente, orientada en las tres esferas, eupneica en reposo. Buen estado general. Glasgow 15. Exploración mamaria: no se aprecian signos de inflamación, ulceración y/o asimetrías. No hay secreción ni retracción de pezón. No se palpan nódulos, masas ni adenopatías regionales. AC: tonos rítmicos, sin soplos. AP: hipoventilación en hemitórax izquierdo. Abdomen: anodino. Sin edemas ni signos de TVP en EEII.\n\nPruebas complementarias\nTC con contraste: nódulos pulmonares de 10 mm en lóbulo superior derecho (LSD), que presenta amplio contacto con pleura y discreta especulación marginal (apariencia atípica para corresponder a enfermedad secundaria) y dos en lóbulo medio (LM) de bordes bien definidos, el mayor de 16 mm.\nAnalítica general: bioquímica y hemograma sin alteraciones relevantes. Marcadores tumorales: Ca 15,3: 23,3 U/ml (0-30). CEA: 18,27 ng/ml (0-4,6).\n\nDiagnóstico\n- Nódulos pulmonares a estudio.\n- Carcinoma ductal infiltrante pT2pN0M0 luminal A.\n\nTratamiento\nNo precisa tratamiento específico en este momento.\n\nEvolución\nSe solicita PET/TC que confirma la existencia de nódulo de 1,3 mm en LSD con SUVmax 6,6 y nódulo de 10 mm en LM con SUVmax de 3; sin otros hallazgos.\nTC craneoencefálica con contraste: no se evidencian imágenes que sugieran existencia de enfermedad secundaria a nivel encefálico. Espacios subaracnoideos de convexidad y sistema ventricular dentro de límites de normalidad.\nTras presentar el caso en Comité de Tumores Tórax, se plantea intervención quirúrgica. El día 26/2/2014 se realiza resección atípica de ambos nódulos pulmonares (16 mm LSD y 12 mm LM), con resultado anatomopatológico de adenocarcinoma acinar focalmente mucosecretor de origen pulmonar G2 (perfil inmunohistoquímico, IHQ: TTF1:+). Determinación: mutación EGFR (RT-PCR Cobas®): negativa. Translocación ALK (IHQ Novocastra®): negativa.\nTras la cirugía se solicita PET/TC que detecta hipercaptación en adenopatías 4R, 7, 10R con SUVmax hasta 4. Tras presentar el caso en comité multidisciplinar, se decide solicitar TC que no muestra hallazgos destacables y ecobroncoscopia (EBUS). Se procede a realizar punción-biopsia de adenopatías 4R y 7 resultando negativas para malignidad con hallazgos inflamatorios.\nContinúa el seguimiento estrecho y en abril/2015 se detecta en TC nódulo pulmonar de 0,6 cm en LSD y aumento de CEA (8). En PET/TC se aprecia micronódulo LSD de 0,5 cm con SUVmax de 1,6 sospechoso de malignidad, sin más datos de enfermedad regional y/o a distancia. Se solicitan además pruebas funcionales respiratorias y broncoscopia, anodina.\nAnte sospecha de recidiva local, se presenta nuevamente en Comité de Tumores Tórax y se plantea cirugía. Se interviene bajo anestesia general, el 25-6-2015 realizándose resección sublobar atípica en cuña de LSD, localizando nódulo en segmento posterior de LSD. El resultado anatomopatológico confirma adenocarcinoma moderadamente diferenciado d ...

# %%
from sklearn.preprocessing import LabelEncoder

lab_encoder = LabelEncoder()
# IOB-2 format
lab_encoder.fit(["B", "I", "O"])
# Out:
# LabelEncoder()

# %% [markdown]
# ### Test corpus
#
# All test texts are considered:

# %%
test_doc_list = sorted(set(df_text_test["doc_id"]))

# %%
len(test_doc_list)
# Out:
# 300

# %%
test_gs_path = corpus_path + "test-set/" + sub_task_path

# %%
exec_path = "predictions/"

# %%
import pickle

def ner_avg_metrics(model_names, model_preds_dict, subtask='ner'):
    # Calculate performance of each individual model
    res_dict = {}
    for model_name in model_names:
        p_res, r_res, f1_res = [], [], []
        for mod_name in model_preds_dict[model_name]:
            # Word predictions
            with open(exec_path + "test_doc_word_preds_" + mod_name + ".pck", "rb") as f:
                arr_doc_seq_preds = pickle.load(f)

            # Word start-send pairs
            with open(exec_path + "test_doc_word_start_end_" + mod_name + ".pck", "rb") as f:
                arr_doc_seq_start_end = pickle.load(f)

            ann_res = []
            for d in tqdm(range(len(test_doc_list))):
                doc = test_doc_list[d]
                arr_seq_preds = arr_doc_seq_preds[d]
                arr_seq_start_end = arr_doc_seq_start_end[d]
                arr_seq_iob_preds = [lab_encoder.classes_[pred] for pred in np.argmax(arr_seq_preds, axis=1)]
                ann_res.extend(extract_seq_preds_iob2(doc_id=doc, iob_seq_preds=arr_seq_iob_preds, 
                                             seq_start_end=arr_seq_start_end, df_text=df_text_test, text_col=text_col))

            ann_res = pd.DataFrame(ann_res)
            p, r, f1 = calculate_ner_metrics(gs=format_ner_gs(test_gs_path, subtask=subtask), 
                                        pred=format_ner_pred_df(gs_path=test_gs_path, df_preds=ann_res))
            p_res.append(p)
            r_res.append(r)
            f1_res.append(f1)
        
        p_res_desc = pd.Series(p_res).describe()
        r_res_desc = pd.Series(r_res).describe()
        f1_res_desc = pd.Series(f1_res).describe()
        
        res_dict[model_name] = {"P_avg": round(p_res_desc['mean'], 3), "P_std": round(p_res_desc['std'], 3), 
                                "P_max": round(p_res_desc['max'], 3),
                                "R_avg": round(r_res_desc['mean'], 3), "R_std": round(r_res_desc['std'], 3), 
                                "R_max": round(r_res_desc['max'], 3),
                                "F1_avg": round(f1_res_desc['mean'], 3), "F1_std": round(f1_res_desc['std'], 3), 
                                "F1_max": round(f1_res_desc['max'], 3)}
        
    return pd.DataFrame(res_dict).transpose()

# %% [markdown]
# ## General-domain

# %%
mbert_scr_names = ["mbert_0", "mbert_1", "mbert_2", "mbert_3", "mbert_4"]

# %%
beto_scr_names = ["beto_0", "beto_1", "beto_2", "beto_3", "beto_4"]

# %%
xlmr_scr_names = ["xlmr_0", "xlmr_1", "xlmr_2", "xlmr_3", "xlmr_4"]

# %%
scr_model_names = ['mBERT', 'BETO', 'XLM-R']
scr_model_dict = {scr_model_names[0]: mbert_scr_names, scr_model_names[1]: beto_scr_names, 
                  scr_model_names[2]: xlmr_scr_names}
scr_model_perf = ner_avg_metrics(model_names=scr_model_names, model_preds_dict=scr_model_dict, subtask='ner')
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 260.88it/s]
# 100%|██████████| 300/300 [00:01<00:00, 253.67it/s]
# 100%|██████████| 300/300 [00:01<00:00, 260.57it/s]
# 100%|██████████| 300/300 [00:01<00:00, 261.40it/s]
# 100%|██████████| 300/300 [00:01<00:00, 255.56it/s]
# 100%|██████████| 300/300 [00:01<00:00, 251.70it/s]
# 100%|██████████| 300/300 [00:01<00:00, 255.75it/s]
# 100%|██████████| 300/300 [00:01<00:00, 258.63it/s]
# 100%|██████████| 300/300 [00:01<00:00, 260.66it/s]
# 100%|██████████| 300/300 [00:01<00:00, 257.34it/s]
# 100%|██████████| 300/300 [00:01<00:00, 252.25it/s]
# 100%|██████████| 300/300 [00:01<00:00, 259.25it/s]
# 100%|██████████| 300/300 [00:01<00:00, 249.39it/s]
# 100%|██████████| 300/300 [00:01<00:00, 249.28it/s]
# 100%|██████████| 300/300 [00:01<00:00, 261.80it/s]

# %%
scr_model_perf
# Out:
#        P_avg  P_std  P_max  R_avg  R_std  R_max  F1_avg  F1_std  F1_max
# mBERT  0.850  0.009  0.861  0.854  0.007  0.862   0.852   0.004   0.858
# BETO   0.850  0.006  0.859  0.858  0.008  0.869   0.854   0.004   0.856
# XLM-R  0.846  0.014  0.861  0.858  0.006  0.863   0.852   0.005   0.858

# %% [markdown]
# ## Galén

# %%
mbert_gal_names = ["mbert_galen_0", "mbert_galen_1", "mbert_galen_2", "mbert_galen_3", "mbert_galen_4"]

# %%
beto_gal_names = ["beto_galen_0", "beto_galen_1", "beto_galen_2", "beto_galen_3", "beto_galen_4"]

# %%
xlmr_gal_names = ["xlmr_galen_0", "xlmr_galen_1","xlmr_galen_2", "xlmr_galen_3", "xlmr_galen_4"]

# %%
gal_model_names = ['mBERT-Galén', 'BETO-Galén', 'XLM-R-Galén']
gal_model_dict = {gal_model_names[0]: mbert_gal_names, gal_model_names[1]: beto_gal_names, 
                  gal_model_names[2]: xlmr_gal_names}
gal_model_perf = ner_avg_metrics(model_names=gal_model_names, model_preds_dict=gal_model_dict, subtask='ner')
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 261.56it/s]
# 100%|██████████| 300/300 [00:01<00:00, 257.43it/s]
# 100%|██████████| 300/300 [00:01<00:00, 254.28it/s]
# 100%|██████████| 300/300 [00:01<00:00, 253.72it/s]
# 100%|██████████| 300/300 [00:01<00:00, 254.50it/s]
# 100%|██████████| 300/300 [00:01<00:00, 253.82it/s]
# 100%|██████████| 300/300 [00:01<00:00, 257.80it/s]
# 100%|██████████| 300/300 [00:01<00:00, 260.10it/s]
# 100%|██████████| 300/300 [00:01<00:00, 255.03it/s]
# 100%|██████████| 300/300 [00:01<00:00, 252.95it/s]
# 100%|██████████| 300/300 [00:01<00:00, 251.08it/s]
# 100%|██████████| 300/300 [00:01<00:00, 254.50it/s]
# 100%|██████████| 300/300 [00:01<00:00, 258.60it/s]
# 100%|██████████| 300/300 [00:01<00:00, 249.32it/s]
# 100%|██████████| 300/300 [00:01<00:00, 255.51it/s]

# %%
gal_model_perf
# Out:
#              P_avg  P_std  P_max  R_avg  R_std  R_max  F1_avg  F1_std  F1_max
# mBERT-Galén  0.867  0.008  0.876  0.869  0.007  0.877   0.868   0.004   0.876
# BETO-Galén   0.872  0.008  0.880  0.865  0.004  0.869   0.868   0.002   0.870
# XLM-R-Galén  0.867  0.009  0.881  0.869  0.006  0.878   0.868   0.003   0.874

# %% [markdown]
# ## Ensemble

# %%
eval_strat = 'prod'

# %%
def compute_metrics_ens(arr_models, doc_list, lb_encoder, df_text, text_col, gs_path, ens_eval_strategy='max', subtask='ner'):
    ens_preds, ens_start_end = [], []
    for mod_name in arr_models:
        # Word predictions
        with open(exec_path + "test_doc_word_preds_" + mod_name + ".pck", "rb") as f:
            ens_preds.append(pickle.load(f))
        # Word start-send pairs
        with open(exec_path + "test_doc_word_start_end_" + mod_name + ".pck", "rb") as f:
            ens_start_end.append(pickle.load(f))
    df_ens_ann = ens_ner_preds_brat_format(doc_list=doc_list, ens_doc_word_preds=ens_preds, 
                          ens_doc_word_start_end=ens_start_end, lb_encoder=lb_encoder, df_text=df_text, 
                          text_col=text_col, strategy=ens_eval_strategy)
    return df_ens_ann, calculate_ner_metrics(gs=format_ner_gs(gs_path, subtask=subtask), 
                      pred=format_ner_pred_df(gs_path=gs_path, df_preds=df_ens_ann))

# %% [markdown]
# ### mBERT

# %%
ens_models = mbert_scr_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 214.50it/s]
# (0.873, 0.872, 0.872)

# %% [markdown]
# ### mBERT-Galén

# %%
ens_models = mbert_gal_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 211.13it/s]
# (0.885, 0.881, 0.883)

# %% [markdown]
# ### BETO

# %%
ens_models = beto_scr_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 213.40it/s]
# (0.876, 0.873, 0.875)

# %% [markdown]
# ### BETO-Galén

# %%
ens_models = beto_gal_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 215.42it/s]
# (0.883, 0.873, 0.878)

# %% [markdown]
# ### XLM-R

# %%
ens_models = xlmr_scr_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 209.93it/s]
# (0.868, 0.874, 0.871)

# %% [markdown]
# ### XLM-R-Galén

# %%
ens_models = xlmr_gal_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 213.75it/s]
# (0.887, 0.879, 0.883)

# %% [markdown]
# ### mBERT + mBERT-Galén

# %%
ens_models = mbert_scr_names + mbert_gal_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 173.62it/s]
# (0.881, 0.876, 0.879)

# %% [markdown]
# ### BETO + BETO-Galén

# %%
ens_models = beto_scr_names + beto_gal_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 175.03it/s]
# (0.887, 0.878, 0.882)

# %% [markdown]
# ### XLM-R + XLM-R-Galén

# %%
ens_models = xlmr_scr_names + xlmr_gal_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 174.13it/s]
# (0.883, 0.88, 0.882)

# %% [markdown]
# ### mBERT + BETO + XLM-R

# %%
ens_models = mbert_scr_names + beto_scr_names + xlmr_scr_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 149.29it/s]
# (0.882, 0.876, 0.879)

# %% [markdown]
# ### mBERT-Galén + BETO-Galén + XLM-R-Galén

# %%
ens_models = mbert_gal_names + beto_gal_names + xlmr_gal_names
df_ens_ann, res_metrics = compute_metrics_ens(arr_models=ens_models, doc_list=test_doc_list, lb_encoder=lab_encoder, 
                    df_text=df_text_test, text_col=text_col, gs_path=test_gs_path, ens_eval_strategy=eval_strat, subtask='ner')
print(res_metrics)
# Out:
# 100%|██████████| 300/300 [00:01<00:00, 151.99it/s]
# (0.893, 0.887, 0.89)

# %%
# Sanity check

# %%
out_test_path = "ens_test_preds/"

# %%
write_ner_ann(df_pred_ann=df_ens_ann, out_path=out_test_path)

# %%
# %%time
# !python ../resources/cantemist-evaluation-library/src/main.py -g ../datasets/cantemist_v6/test-set/cantemist-ner/ -p ./ens_test_preds/ -s ner
# Out:
# -----------------------------------------------------
# Clinical case name			Precision
# -----------------------------------------------------
# cc_onco1006.ann		1.0
# -----------------------------------------------------
# cc_onco1023.ann		1.0
# -----------------------------------------------------
# cc_onco1027.ann		0.667
# -----------------------------------------------------
# cc_onco1038.ann		0.769
# -----------------------------------------------------
# cc_onco104.ann		0.917
# -----------------------------------------------------
# cc_onco1040.ann		0.938
# -----------------------------------------------------
# cc_onco1044.ann		0.889
# -----------------------------------------------------
# cc_onco1046.ann		1.0
# -----------------------------------------------------
# cc_onco1051.ann		1.0
# -----------------------------------------------------
# cc_onco1056.ann		1.0
# -----------------------------------------------------
# cc_onco1057.ann		0.812
# -----------------------------------------------------
# cc_onco1059.ann		0.857
# -----------------------------------------------------
# cc_onco1064.ann		1.0
# -----------------------------------------------------
# cc_onco1065.ann		0.5
# -----------------------------------------------------
# cc_onco1066.ann		0.9
# -----------------------------------------------------
# cc_onco1075.ann		1.0
# -----------------------------------------------------
# cc_onco1078.ann		0.769
# -----------------------------------------------------
# cc_onco1080.ann		1.0
# -----------------------------------------------------
# cc_onco1083.ann		1.0
# -----------------------------------------------------
# cc_onco1084.ann		0.6
# -----------------------------------------------------
# cc_onco1085.ann		1.0
# -----------------------------------------------------
# cc_onco1092.ann		1.0
# -----------------------------------------------------
# cc_onco1096.ann		1.0
# -----------------------------------------------------
# cc_onco1108.ann		1.0
# -----------------------------------------------------
# cc_onco1110.ann		1.0
# -----------------------------------------------------
# cc_onco1113.ann		0.6
# -----------------------------------------------------
# cc_onco1116.ann		1.0
# -----------------------------------------------------
# cc_onco112.ann		1.0
# -----------------------------------------------------
# cc_onco1120.ann		1.0
# -----------------------------------------------------
# cc_onco1125.ann		1.0
# -----------------------------------------------------
# cc_onco1126.ann		0.75
# -----------------------------------------------------
# cc_onco1129.ann		0.909
# -----------------------------------------------------
# cc_onco113.ann		0.952
# -----------------------------------------------------
# cc_onco1135.ann		1.0
# -----------------------------------------------------
# cc_onco1139.ann		0.92
# -----------------------------------------------------
# cc_onco1149.ann		0.917
# -----------------------------------------------------
# cc_onco1156.ann		0.6
# -----------------------------------------------------
# cc_onco1158.ann		0.889
# -----------------------------------------------------
# cc_onco1160.ann		0.786
# -----------------------------------------------------
# cc_onco1161.ann		1.0
# -----------------------------------------------------
# cc_onco1162.ann		0.714
# -----------------------------------------------------
# cc_onco1165.ann		0.917
# -----------------------------------------------------
# cc_onco1169.ann		0.667
# -----------------------------------------------------
# cc_onco1174.ann		0.882
# -----------------------------------------------------
# cc_onco1185.ann		1.0
# -----------------------------------------------------
# cc_onco1190.ann		1.0
# -----------------------------------------------------
# cc_onco1191.ann		0.778
# -----------------------------------------------------
# cc_onco1197.ann		0.818
# -----------------------------------------------------
# cc_onco12.ann		1.0
# -----------------------------------------------------
# cc_onco1200.ann		1.0
# -----------------------------------------------------
# cc_onco1204.ann		0.875
# -----------------------------------------------------
# cc_onco1206.ann		1.0
# -----------------------------------------------------
# cc_onco1209.ann		0.864
# -----------------------------------------------------
# cc_onco1212.ann		0.917
# -----------------------------------------------------
# cc_onco1214.ann		1.0
# -----------------------------------------------------
# cc_onco1219.ann		0.947
# -----------------------------------------------------
# cc_onco122.ann		0.656
# -----------------------------------------------------
# cc_onco1223.ann		1.0
# -----------------------------------------------------
# cc_onco1231.ann		1.0
# -----------------------------------------------------
# cc_onco1242.ann		1.0
# -----------------------------------------------------
# cc_onco1244.ann		0.929
# -----------------------------------------------------
# cc_onco1250.ann		1.0
# -----------------------------------------------------
# cc_onco1259.ann		1.0
# -----------------------------------------------------
# cc_onco1261.ann		1.0
# -----------------------------------------------------
# cc_onco1263.ann		1.0
# -----------------------------------------------------
# cc_onco1266.ann		0.2
# -----------------------------------------------------
# cc_onco1268.ann		0.8
# -----------------------------------------------------
# cc_onco1269.ann		0.846
# -----------------------------------------------------
# cc_onco1274.ann		0.867
# -----------------------------------------------------
# cc_onco1282.ann		0.9
# -----------------------------------------------------
# cc_onco1285.ann		0.875
# -----------------------------------------------------
# cc_onco1288.ann		1.0
# -----------------------------------------------------
# cc_onco1290.ann		1.0
# -----------------------------------------------------
# cc_onco1292.ann		1.0
# -----------------------------------------------------
# cc_onco1294.ann		1.0
# -----------------------------------------------------
# cc_onco1297.ann		0.846
# -----------------------------------------------------
# cc_onco1298.ann		0.8
# -----------------------------------------------------
# cc_onco1299.ann		0.8
# -----------------------------------------------------
# cc_onco130.ann		0.857
# -----------------------------------------------------
# cc_onco1302.ann		1.0
# -----------------------------------------------------
# cc_onco1303.ann		0.769
# -----------------------------------------------------
# cc_onco1309.ann		0.875
# -----------------------------------------------------
# cc_onco1313.ann		1.0
# -----------------------------------------------------
# cc_onco1316.ann		1.0
# -----------------------------------------------------
# cc_onco132.ann		1.0
# -----------------------------------------------------
# cc_onco1321.ann		0.9
# -----------------------------------------------------
# cc_onco1322.ann		1.0
# -----------------------------------------------------
# cc_onco1334.ann		1.0
# -----------------------------------------------------
# cc_onco1342.ann		0.2
# -----------------------------------------------------
# cc_onco1343.ann		1.0
# -----------------------------------------------------
# cc_onco1344.ann		0.818
# -----------------------------------------------------
# cc_onco1345.ann		1.0
# -----------------------------------------------------
# cc_onco1349.ann		1.0
# -----------------------------------------------------
# cc_onco1352.ann		0.818
# -----------------------------------------------------
# cc_onco1357.ann		0.5
# -----------------------------------------------------
# cc_onco136.ann		0.533
# -----------------------------------------------------
# cc_onco1360.ann		1.0
# -----------------------------------------------------
# cc_onco1362.ann		1.0
# -----------------------------------------------------
# cc_onco1364.ann		0.778
# -----------------------------------------------------
# cc_onco1366.ann		0.7
# -----------------------------------------------------
# cc_onco1367.ann		1.0
# -----------------------------------------------------
# cc_onco1370.ann		0.833
# -----------------------------------------------------
# cc_onco1378.ann		1.0
# -----------------------------------------------------
# cc_onco1379.ann		1.0
# -----------------------------------------------------
# cc_onco1381.ann		0.769
# -----------------------------------------------------
# cc_onco1385.ann		0.714
# -----------------------------------------------------
# cc_onco139.ann		1.0
# -----------------------------------------------------
# cc_onco1398.ann		0.818
# -----------------------------------------------------
# cc_onco1401.ann		0.857
# -----------------------------------------------------
# cc_onco1403.ann		0.923
# -----------------------------------------------------
# cc_onco1406.ann		1.0
# -----------------------------------------------------
# cc_onco1410.ann		0.625
# -----------------------------------------------------
# cc_onco1411.ann		0.75
# -----------------------------------------------------
# cc_onco1416.ann		0.909
# -----------------------------------------------------
# cc_onco1423.ann		1.0
# -----------------------------------------------------
# cc_onco1426.ann		0.857
# -----------------------------------------------------
# cc_onco1430.ann		0.6
# -----------------------------------------------------
# cc_onco1433.ann		1.0
# -----------------------------------------------------
# cc_onco1434.ann		1.0
# -----------------------------------------------------
# cc_onco1439.ann		1.0
# -----------------------------------------------------
# cc_onco1446.ann		1.0
# -----------------------------------------------------
# cc_onco1450.ann		0.667
# -----------------------------------------------------
# cc_onco1452.ann		1.0
# -----------------------------------------------------
# cc_onco1453.ann		0.818
# -----------------------------------------------------
# cc_onco1454.ann		1.0
# -----------------------------------------------------
# cc_onco1455.ann		1.0
# -----------------------------------------------------
# cc_onco1458.ann		1.0
# -----------------------------------------------------
# cc_onco1460.ann		0.889
# -----------------------------------------------------
# cc_onco1466.ann		0.944
# -----------------------------------------------------
# cc_onco1469.ann		0.929
# -----------------------------------------------------
# cc_onco1472.ann		0.5
# -----------------------------------------------------
# cc_onco1473.ann		0.905
# -----------------------------------------------------
# cc_onco1479.ann		0.818
# -----------------------------------------------------
# cc_onco1480.ann		0.714
# -----------------------------------------------------
# cc_onco1483.ann		0.909
# -----------------------------------------------------
# cc_onco1485.ann		0.7
# -----------------------------------------------------
# cc_onco1489.ann		1.0
# -----------------------------------------------------
# cc_onco1491.ann		0.778
# -----------------------------------------------------
# cc_onco1496.ann		0.875
# -----------------------------------------------------
# cc_onco1499.ann		1.0
# -----------------------------------------------------
# cc_onco151.ann		0.842
# -----------------------------------------------------
# cc_onco172.ann		0.944
# -----------------------------------------------------
# cc_onco178.ann		1.0
# -----------------------------------------------------
# cc_onco179.ann		0.968
# -----------------------------------------------------
# cc_onco190.ann		0.929
# -----------------------------------------------------
# cc_onco191.ann		1.0
# -----------------------------------------------------
# cc_onco221.ann		0.857
# -----------------------------------------------------
# cc_onco228.ann		1.0
# -----------------------------------------------------
# cc_onco238.ann		0.889
# -----------------------------------------------------
# cc_onco24.ann		0.81
# -----------------------------------------------------
# cc_onco240.ann		1.0
# -----------------------------------------------------
# cc_onco241.ann		0.786
# -----------------------------------------------------
# cc_onco242.ann		1.0
# -----------------------------------------------------
# cc_onco248.ann		1.0
# -----------------------------------------------------
# cc_onco260.ann		1.0
# -----------------------------------------------------
# cc_onco268.ann		1.0
# -----------------------------------------------------
# cc_onco270.ann		1.0
# -----------------------------------------------------
# cc_onco281.ann		1.0
# -----------------------------------------------------
# cc_onco283.ann		1.0
# -----------------------------------------------------
# cc_onco285.ann		1.0
# -----------------------------------------------------
# cc_onco287.ann		0.833
# -----------------------------------------------------
# cc_onco290.ann		1.0
# -----------------------------------------------------
# cc_onco292.ann		0.929
# -----------------------------------------------------
# cc_onco294.ann		1.0
# -----------------------------------------------------
# cc_onco304.ann		0.889
# -----------------------------------------------------
# cc_onco305.ann		0.88
# -----------------------------------------------------
# cc_onco323.ann		1.0
# -----------------------------------------------------
# cc_onco329.ann		1.0
# -----------------------------------------------------
# cc_onco33.ann		0.909
# -----------------------------------------------------
# cc_onco332.ann		0.95
# -----------------------------------------------------
# cc_onco333.ann		1.0
# -----------------------------------------------------
# cc_onco339.ann		0.923
# -----------------------------------------------------
# cc_onco349.ann		0.857
# -----------------------------------------------------
# cc_onco359.ann		0.875
# -----------------------------------------------------
# cc_onco365.ann		0.5
# -----------------------------------------------------
# cc_onco373.ann		0.833
# -----------------------------------------------------
# cc_onco383.ann		1.0
# -----------------------------------------------------
# cc_onco389.ann		0.788
# -----------------------------------------------------
# cc_onco397.ann		0.923
# -----------------------------------------------------
# cc_onco399.ann		0.882
# -----------------------------------------------------
# cc_onco410.ann		0.909
# -----------------------------------------------------
# cc_onco414.ann		1.0
# -----------------------------------------------------
# cc_onco421.ann		1.0
# -----------------------------------------------------
# cc_onco431.ann		0.88
# -----------------------------------------------------
# cc_onco441.ann		0.889
# -----------------------------------------------------
# cc_onco447.ann		1.0
# -----------------------------------------------------
# cc_onco448.ann		0.692
# -----------------------------------------------------
# cc_onco451.ann		0.923
# -----------------------------------------------------
# cc_onco454.ann		1.0
# -----------------------------------------------------
# cc_onco456.ann		0.929
# -----------------------------------------------------
# cc_onco465.ann		0.963
# -----------------------------------------------------
# cc_onco47.ann		0.917
# -----------------------------------------------------
# cc_onco471.ann		1.0
# -----------------------------------------------------
# cc_onco476.ann		0.9
# -----------------------------------------------------
# cc_onco484.ann		0.739
# -----------------------------------------------------
# cc_onco487.ann		0.5
# -----------------------------------------------------
# cc_onco494.ann		0.857
# -----------------------------------------------------
# cc_onco495.ann		0.889
# -----------------------------------------------------
# cc_onco497.ann		0.333
# -----------------------------------------------------
# cc_onco505.ann		0.875
# -----------------------------------------------------
# cc_onco508.ann		1.0
# -----------------------------------------------------
# cc_onco511.ann		0.889
# -----------------------------------------------------
# cc_onco512.ann		1.0
# -----------------------------------------------------
# cc_onco514.ann		0.929
# -----------------------------------------------------
# cc_onco515.ann		0.8
# -----------------------------------------------------
# cc_onco52.ann		0.8
# -----------------------------------------------------
# cc_onco524.ann		0.75
# -----------------------------------------------------
# cc_onco526.ann		1.0
# -----------------------------------------------------
# cc_onco527.ann		0.882
# -----------------------------------------------------
# cc_onco53.ann		0.875
# -----------------------------------------------------
# cc_onco532.ann		0.778
# -----------------------------------------------------
# cc_onco539.ann		1.0
# -----------------------------------------------------
# cc_onco540.ann		1.0
# -----------------------------------------------------
# cc_onco546.ann		0.9
# -----------------------------------------------------
# cc_onco548.ann		0.833
# -----------------------------------------------------
# cc_onco549.ann		0.917
# -----------------------------------------------------
# cc_onco561.ann		0.667
# -----------------------------------------------------
# cc_onco564.ann		0.684
# -----------------------------------------------------
# cc_onco574.ann		0.857
# -----------------------------------------------------
# cc_onco584.ann		0.944
# -----------------------------------------------------
# cc_onco589.ann		1.0
# -----------------------------------------------------
# cc_onco600.ann		1.0
# -----------------------------------------------------
# cc_onco601.ann		0.857
# -----------------------------------------------------
# cc_onco604.ann		0.5
# -----------------------------------------------------
# cc_onco607.ann		1.0
# -----------------------------------------------------
# cc_onco611.ann		0.929
# -----------------------------------------------------
# cc_onco621.ann		0.943
# -----------------------------------------------------
# cc_onco624.ann		0.909
# -----------------------------------------------------
# cc_onco627.ann		0.812
# -----------------------------------------------------
# cc_onco629.ann		0.917
# -----------------------------------------------------
# cc_onco632.ann		0.833
# -----------------------------------------------------
# cc_onco637.ann		1.0
# -----------------------------------------------------
# cc_onco641.ann		0.846
# -----------------------------------------------------
# cc_onco651.ann		0.7
# -----------------------------------------------------
# cc_onco656.ann		0.955
# -----------------------------------------------------
# cc_onco659.ann		1.0
# -----------------------------------------------------
# cc_onco660.ann		0.667
# -----------------------------------------------------
# cc_onco661.ann		0.857
# -----------------------------------------------------
# cc_onco664.ann		1.0
# -----------------------------------------------------
# cc_onco680.ann		1.0
# -----------------------------------------------------
# cc_onco683.ann		0.875
# -----------------------------------------------------
# cc_onco69.ann		0.933
# -----------------------------------------------------
# cc_onco693.ann		0.96
# -----------------------------------------------------
# cc_onco701.ann		1.0
# -----------------------------------------------------
# cc_onco712.ann		0.905
# -----------------------------------------------------
# cc_onco715.ann		1.0
# -----------------------------------------------------
# cc_onco72.ann		0.952
# -----------------------------------------------------
# cc_onco722.ann		1.0
# -----------------------------------------------------
# cc_onco742.ann		0.917
# -----------------------------------------------------
# cc_onco748.ann		0.933
# -----------------------------------------------------
# cc_onco749.ann		1.0
# -----------------------------------------------------
# cc_onco75.ann		1.0
# -----------------------------------------------------
# cc_onco750.ann		1.0
# -----------------------------------------------------
# cc_onco756.ann		1.0
# -----------------------------------------------------
# cc_onco770.ann		0.862
# -----------------------------------------------------
# cc_onco772.ann		0.81
# -----------------------------------------------------
# cc_onco775.ann		0.867
# -----------------------------------------------------
# cc_onco781.ann		0.8
# -----------------------------------------------------
# cc_onco782.ann		1.0
# -----------------------------------------------------
# cc_onco785.ann		0.882
# -----------------------------------------------------
# cc_onco793.ann		0.364
# -----------------------------------------------------
# cc_onco801.ann		0.947
# -----------------------------------------------------
# cc_onco805.ann		1.0
# -----------------------------------------------------
# cc_onco809.ann		0.778
# -----------------------------------------------------
# cc_onco810.ann		0.8
# -----------------------------------------------------
# cc_onco811.ann		0.938
# -----------------------------------------------------
# cc_onco812.ann		1.0
# -----------------------------------------------------
# cc_onco822.ann		1.0
# -----------------------------------------------------
# cc_onco827.ann		1.0
# -----------------------------------------------------
# cc_onco831.ann		0.923
# -----------------------------------------------------
# cc_onco834.ann		0.6
# -----------------------------------------------------
# cc_onco838.ann		0.867
# -----------------------------------------------------
# cc_onco842.ann		1.0
# -----------------------------------------------------
# cc_onco843.ann		0.815
# -----------------------------------------------------
# cc_onco855.ann		0.786
# -----------------------------------------------------
# cc_onco867.ann		0.733
# -----------------------------------------------------
# cc_onco877.ann		0.828
# -----------------------------------------------------
# cc_onco880.ann		1.0
# -----------------------------------------------------
# cc_onco881.ann		0.778
# -----------------------------------------------------
# cc_onco887.ann		1.0
# -----------------------------------------------------
# cc_onco89.ann		1.0
# -----------------------------------------------------
# cc_onco899.ann		1.0
# -----------------------------------------------------
# cc_onco9.ann		0.875
# -----------------------------------------------------
# cc_onco901.ann		0.571
# -----------------------------------------------------
# cc_onco902.ann		0.833
# -----------------------------------------------------
# cc_onco926.ann		0.857
# -----------------------------------------------------
# cc_onco928.ann		0.818
# -----------------------------------------------------
# cc_onco938.ann		0.958
# -----------------------------------------------------
# cc_onco94.ann		1.0
# -----------------------------------------------------
# cc_onco941.ann		0.692
# -----------------------------------------------------
# cc_onco943.ann		0.667
# -----------------------------------------------------
# cc_onco950.ann		1.0
# -----------------------------------------------------
# cc_onco953.ann		1.0
# -----------------------------------------------------
# cc_onco956.ann		1.0
# -----------------------------------------------------
# cc_onco958.ann		0.929
# -----------------------------------------------------
# cc_onco960.ann		0.647
# -----------------------------------------------------
# cc_onco964.ann		1.0
# -----------------------------------------------------
# cc_onco975.ann		0.929
# -----------------------------------------------------
# cc_onco977.ann		0.889
# -----------------------------------------------------
# cc_onco978.ann		1.0
# -----------------------------------------------------
#
# -----------------------------------------------------
# Clinical case name			Recall
# -----------------------------------------------------
# cc_onco1006.ann		1.0
# -----------------------------------------------------
# cc_onco1023.ann		0.882
# -----------------------------------------------------
# cc_onco1027.ann		0.4
# -----------------------------------------------------
# cc_onco1038.ann		0.952
# -----------------------------------------------------
# cc_onco104.ann		0.846
# -----------------------------------------------------
# cc_onco1040.ann		0.882
# -----------------------------------------------------
# cc_onco1044.ann		1.0
# -----------------------------------------------------
# cc_onco1046.ann		0.625
# -----------------------------------------------------
# cc_onco1051.ann		0.647
# -----------------------------------------------------
# cc_onco1056.ann		1.0
# -----------------------------------------------------
# cc_onco1057.ann		0.929
# -----------------------------------------------------
# cc_onco1059.ann		0.789
# -----------------------------------------------------
# cc_onco1064.ann		0.75
# -----------------------------------------------------
# cc_onco1065.ann		0.571
# -----------------------------------------------------
# cc_onco1066.ann		1.0
# -----------------------------------------------------
# cc_onco1075.ann		1.0
# -----------------------------------------------------
# cc_onco1078.ann		0.909
# -----------------------------------------------------
# cc_onco1080.ann		1.0
# -----------------------------------------------------
# cc_onco1083.ann		1.0
# -----------------------------------------------------
# cc_onco1084.ann		0.75
# -----------------------------------------------------
# cc_onco1085.ann		1.0
# -----------------------------------------------------
# cc_onco1092.ann		1.0
# -----------------------------------------------------
# cc_onco1096.ann		0.938
# -----------------------------------------------------
# cc_onco1108.ann		1.0
# -----------------------------------------------------
# cc_onco1110.ann		1.0
# -----------------------------------------------------
# cc_onco1113.ann		1.0
# -----------------------------------------------------
# cc_onco1116.ann		1.0
# -----------------------------------------------------
# cc_onco112.ann		1.0
# -----------------------------------------------------
# cc_onco1120.ann		1.0
# -----------------------------------------------------
# cc_onco1125.ann		1.0
# -----------------------------------------------------
# cc_onco1126.ann		0.75
# -----------------------------------------------------
# cc_onco1129.ann		0.952
# -----------------------------------------------------
# cc_onco113.ann		0.952
# -----------------------------------------------------
# cc_onco1135.ann		1.0
# -----------------------------------------------------
# cc_onco1139.ann		0.885
# -----------------------------------------------------
# cc_onco1149.ann		0.917
# -----------------------------------------------------
# cc_onco1156.ann		0.6
# -----------------------------------------------------
# cc_onco1158.ann		0.8
# -----------------------------------------------------
# cc_onco1160.ann		0.846
# -----------------------------------------------------
# cc_onco1161.ann		0.889
# -----------------------------------------------------
# cc_onco1162.ann		1.0
# -----------------------------------------------------
# cc_onco1165.ann		0.846
# -----------------------------------------------------
# cc_onco1169.ann		0.75
# -----------------------------------------------------
# cc_onco1174.ann		0.833
# -----------------------------------------------------
# cc_onco1185.ann		1.0
# -----------------------------------------------------
# cc_onco1190.ann		1.0
# -----------------------------------------------------
# cc_onco1191.ann		0.636
# -----------------------------------------------------
# cc_onco1197.ann		1.0
# -----------------------------------------------------
# cc_onco12.ann		1.0
# -----------------------------------------------------
# cc_onco1200.ann		1.0
# -----------------------------------------------------
# cc_onco1204.ann		0.875
# -----------------------------------------------------
# cc_onco1206.ann		1.0
# -----------------------------------------------------
# cc_onco1209.ann		0.905
# -----------------------------------------------------
# cc_onco1212.ann		0.846
# -----------------------------------------------------
# cc_onco1214.ann		1.0
# -----------------------------------------------------
# cc_onco1219.ann		0.9
# -----------------------------------------------------
# cc_onco122.ann		0.808
# -----------------------------------------------------
# cc_onco1223.ann		1.0
# -----------------------------------------------------
# cc_onco1231.ann		1.0
# -----------------------------------------------------
# cc_onco1242.ann		1.0
# -----------------------------------------------------
# cc_onco1244.ann		1.0
# -----------------------------------------------------
# cc_onco1250.ann		1.0
# -----------------------------------------------------
# cc_onco1259.ann		1.0
# -----------------------------------------------------
# cc_onco1261.ann		0.857
# -----------------------------------------------------
# cc_onco1263.ann		1.0
# -----------------------------------------------------
# cc_onco1266.ann		0.5
# -----------------------------------------------------
# cc_onco1268.ann		0.667
# -----------------------------------------------------
# cc_onco1269.ann		0.846
# -----------------------------------------------------
# cc_onco1274.ann		1.0
# -----------------------------------------------------
# cc_onco1282.ann		0.9
# -----------------------------------------------------
# cc_onco1285.ann		0.875
# -----------------------------------------------------
# cc_onco1288.ann		1.0
# -----------------------------------------------------
# cc_onco1290.ann		0.833
# -----------------------------------------------------
# cc_onco1292.ann		1.0
# -----------------------------------------------------
# cc_onco1294.ann		0.889
# -----------------------------------------------------
# cc_onco1297.ann		0.846
# -----------------------------------------------------
# cc_onco1298.ann		0.8
# -----------------------------------------------------
# cc_onco1299.ann		0.8
# -----------------------------------------------------
# cc_onco130.ann		1.0
# -----------------------------------------------------
# cc_onco1302.ann		0.941
# -----------------------------------------------------
# cc_onco1303.ann		0.909
# -----------------------------------------------------
# cc_onco1309.ann		0.875
# -----------------------------------------------------
# cc_onco1313.ann		1.0
# -----------------------------------------------------
# cc_onco1316.ann		0.909
# -----------------------------------------------------
# cc_onco132.ann		1.0
# -----------------------------------------------------
# cc_onco1321.ann		0.9
# -----------------------------------------------------
# cc_onco1322.ann		0.889
# -----------------------------------------------------
# cc_onco1334.ann		1.0
# -----------------------------------------------------
# cc_onco1342.ann		0.5
# -----------------------------------------------------
# cc_onco1343.ann		0.75
# -----------------------------------------------------
# cc_onco1344.ann		0.818
# -----------------------------------------------------
# cc_onco1345.ann		1.0
# -----------------------------------------------------
# cc_onco1349.ann		1.0
# -----------------------------------------------------
# cc_onco1352.ann		1.0
# -----------------------------------------------------
# cc_onco1357.ann		0.667
# -----------------------------------------------------
# cc_onco136.ann		0.727
# -----------------------------------------------------
# cc_onco1360.ann		0.727
# -----------------------------------------------------
# cc_onco1362.ann		1.0
# -----------------------------------------------------
# cc_onco1364.ann		0.778
# -----------------------------------------------------
# cc_onco1366.ann		1.0
# -----------------------------------------------------
# cc_onco1367.ann		0.833
# -----------------------------------------------------
# cc_onco1370.ann		1.0
# -----------------------------------------------------
# cc_onco1378.ann		1.0
# -----------------------------------------------------
# cc_onco1379.ann		1.0
# -----------------------------------------------------
# cc_onco1381.ann		0.909
# -----------------------------------------------------
# cc_onco1385.ann		0.909
# -----------------------------------------------------
# cc_onco139.ann		1.0
# -----------------------------------------------------
# cc_onco1398.ann		0.818
# -----------------------------------------------------
# cc_onco1401.ann		0.857
# -----------------------------------------------------
# cc_onco1403.ann		1.0
# -----------------------------------------------------
# cc_onco1406.ann		1.0
# -----------------------------------------------------
# cc_onco1410.ann		0.714
# -----------------------------------------------------
# cc_onco1411.ann		0.9
# -----------------------------------------------------
# cc_onco1416.ann		0.833
# -----------------------------------------------------
# cc_onco1423.ann		1.0
# -----------------------------------------------------
# cc_onco1426.ann		0.75
# -----------------------------------------------------
# cc_onco1430.ann		0.75
# -----------------------------------------------------
# cc_onco1433.ann		1.0
# -----------------------------------------------------
# cc_onco1434.ann		1.0
# -----------------------------------------------------
# cc_onco1439.ann		0.875
# -----------------------------------------------------
# cc_onco1446.ann		1.0
# -----------------------------------------------------
# cc_onco1450.ann		1.0
# -----------------------------------------------------
# cc_onco1452.ann		1.0
# -----------------------------------------------------
# cc_onco1453.ann		1.0
# -----------------------------------------------------
# cc_onco1454.ann		1.0
# -----------------------------------------------------
# cc_onco1455.ann		1.0
# -----------------------------------------------------
# cc_onco1458.ann		1.0
# -----------------------------------------------------
# cc_onco1460.ann		0.571
# -----------------------------------------------------
# cc_onco1466.ann		1.0
# -----------------------------------------------------
# cc_onco1469.ann		0.867
# -----------------------------------------------------
# cc_onco1472.ann		0.167
# -----------------------------------------------------
# cc_onco1473.ann		0.704
# -----------------------------------------------------
# cc_onco1479.ann		0.643
# -----------------------------------------------------
# cc_onco1480.ann		0.769
# -----------------------------------------------------
# cc_onco1483.ann		0.833
# -----------------------------------------------------
# cc_onco1485.ann		0.636
# -----------------------------------------------------
# cc_onco1489.ann		1.0
# -----------------------------------------------------
# cc_onco1491.ann		0.583
# -----------------------------------------------------
# cc_onco1496.ann		0.933
# -----------------------------------------------------
# cc_onco1499.ann		1.0
# -----------------------------------------------------
# cc_onco151.ann		0.941
# -----------------------------------------------------
# cc_onco172.ann		0.944
# -----------------------------------------------------
# cc_onco178.ann		1.0
# -----------------------------------------------------
# cc_onco179.ann		0.833
# -----------------------------------------------------
# cc_onco190.ann		0.929
# -----------------------------------------------------
# cc_onco191.ann		1.0
# -----------------------------------------------------
# cc_onco221.ann		1.0
# -----------------------------------------------------
# cc_onco228.ann		1.0
# -----------------------------------------------------
# cc_onco238.ann		0.941
# -----------------------------------------------------
# cc_onco24.ann		0.607
# -----------------------------------------------------
# cc_onco240.ann		1.0
# -----------------------------------------------------
# cc_onco241.ann		0.917
# -----------------------------------------------------
# cc_onco242.ann		0.909
# -----------------------------------------------------
# cc_onco248.ann		1.0
# -----------------------------------------------------
# cc_onco260.ann		1.0
# -----------------------------------------------------
# cc_onco268.ann		1.0
# -----------------------------------------------------
# cc_onco270.ann		0.905
# -----------------------------------------------------
# cc_onco281.ann		0.933
# -----------------------------------------------------
# cc_onco283.ann		0.722
# -----------------------------------------------------
# cc_onco285.ann		1.0
# -----------------------------------------------------
# cc_onco287.ann		0.909
# -----------------------------------------------------
# cc_onco290.ann		1.0
# -----------------------------------------------------
# cc_onco292.ann		0.929
# -----------------------------------------------------
# cc_onco294.ann		1.0
# -----------------------------------------------------
# cc_onco304.ann		0.8
# -----------------------------------------------------
# cc_onco305.ann		0.917
# -----------------------------------------------------
# cc_onco323.ann		0.8
# -----------------------------------------------------
# cc_onco329.ann		0.8
# -----------------------------------------------------
# cc_onco33.ann		0.833
# -----------------------------------------------------
# cc_onco332.ann		0.95
# -----------------------------------------------------
# cc_onco333.ann		1.0
# -----------------------------------------------------
# cc_onco339.ann		0.857
# -----------------------------------------------------
# cc_onco349.ann		1.0
# -----------------------------------------------------
# cc_onco359.ann		0.778
# -----------------------------------------------------
# cc_onco365.ann		0.5
# -----------------------------------------------------
# cc_onco373.ann		0.833
# -----------------------------------------------------
# cc_onco383.ann		1.0
# -----------------------------------------------------
# cc_onco389.ann		0.839
# -----------------------------------------------------
# cc_onco397.ann		0.857
# -----------------------------------------------------
# cc_onco399.ann		0.938
# -----------------------------------------------------
# cc_onco410.ann		0.909
# -----------------------------------------------------
# cc_onco414.ann		1.0
# -----------------------------------------------------
# cc_onco421.ann		1.0
# -----------------------------------------------------
# cc_onco431.ann		0.917
# -----------------------------------------------------
# cc_onco441.ann		0.889
# -----------------------------------------------------
# cc_onco447.ann		1.0
# -----------------------------------------------------
# cc_onco448.ann		0.75
# -----------------------------------------------------
# cc_onco451.ann		1.0
# -----------------------------------------------------
# cc_onco454.ann		1.0
# -----------------------------------------------------
# cc_onco456.ann		1.0
# -----------------------------------------------------
# cc_onco465.ann		0.867
# -----------------------------------------------------
# cc_onco47.ann		0.88
# -----------------------------------------------------
# cc_onco471.ann		1.0
# -----------------------------------------------------
# cc_onco476.ann		1.0
# -----------------------------------------------------
# cc_onco484.ann		0.773
# -----------------------------------------------------
# cc_onco487.ann		1.0
# -----------------------------------------------------
# cc_onco494.ann		0.857
# -----------------------------------------------------
# cc_onco495.ann		1.0
# -----------------------------------------------------
# cc_onco497.ann		1.0
# -----------------------------------------------------
# cc_onco505.ann		0.875
# -----------------------------------------------------
# cc_onco508.ann		1.0
# -----------------------------------------------------
# cc_onco511.ann		0.727
# -----------------------------------------------------
# cc_onco512.ann		1.0
# -----------------------------------------------------
# cc_onco514.ann		0.929
# -----------------------------------------------------
# cc_onco515.ann		1.0
# -----------------------------------------------------
# cc_onco52.ann		0.8
# -----------------------------------------------------
# cc_onco524.ann		0.857
# -----------------------------------------------------
# cc_onco526.ann		1.0
# -----------------------------------------------------
# cc_onco527.ann		0.882
# -----------------------------------------------------
# cc_onco53.ann		0.933
# -----------------------------------------------------
# cc_onco532.ann		0.583
# -----------------------------------------------------
# cc_onco539.ann		1.0
# -----------------------------------------------------
# cc_onco540.ann		1.0
# -----------------------------------------------------
# cc_onco546.ann		0.818
# -----------------------------------------------------
# cc_onco548.ann		0.833
# -----------------------------------------------------
# cc_onco549.ann		0.88
# -----------------------------------------------------
# cc_onco561.ann		1.0
# -----------------------------------------------------
# cc_onco564.ann		0.812
# -----------------------------------------------------
# cc_onco574.ann		1.0
# -----------------------------------------------------
# cc_onco584.ann		0.586
# -----------------------------------------------------
# cc_onco589.ann		0.9
# -----------------------------------------------------
# cc_onco600.ann		0.714
# -----------------------------------------------------
# cc_onco601.ann		1.0
# -----------------------------------------------------
# cc_onco604.ann		1.0
# -----------------------------------------------------
# cc_onco607.ann		1.0
# -----------------------------------------------------
# cc_onco611.ann		1.0
# -----------------------------------------------------
# cc_onco621.ann		0.971
# -----------------------------------------------------
# cc_onco624.ann		0.833
# -----------------------------------------------------
# cc_onco627.ann		0.867
# -----------------------------------------------------
# cc_onco629.ann		0.688
# -----------------------------------------------------
# cc_onco632.ann		0.5
# -----------------------------------------------------
# cc_onco637.ann		1.0
# -----------------------------------------------------
# cc_onco641.ann		0.957
# -----------------------------------------------------
# cc_onco651.ann		0.5
# -----------------------------------------------------
# cc_onco656.ann		0.955
# -----------------------------------------------------
# cc_onco659.ann		1.0
# -----------------------------------------------------
# cc_onco660.ann		0.8
# -----------------------------------------------------
# cc_onco661.ann		0.857
# -----------------------------------------------------
# cc_onco664.ann		0.857
# -----------------------------------------------------
# cc_onco680.ann		0.667
# -----------------------------------------------------
# cc_onco683.ann		0.75
# -----------------------------------------------------
# cc_onco69.ann		1.0
# -----------------------------------------------------
# cc_onco693.ann		0.923
# -----------------------------------------------------
# cc_onco701.ann		1.0
# -----------------------------------------------------
# cc_onco712.ann		0.864
# -----------------------------------------------------
# cc_onco715.ann		1.0
# -----------------------------------------------------
# cc_onco72.ann		0.952
# -----------------------------------------------------
# cc_onco722.ann		1.0
# -----------------------------------------------------
# cc_onco742.ann		0.917
# -----------------------------------------------------
# cc_onco748.ann		0.933
# -----------------------------------------------------
# cc_onco749.ann		1.0
# -----------------------------------------------------
# cc_onco75.ann		1.0
# -----------------------------------------------------
# cc_onco750.ann		1.0
# -----------------------------------------------------
# cc_onco756.ann		1.0
# -----------------------------------------------------
# cc_onco770.ann		0.893
# -----------------------------------------------------
# cc_onco772.ann		0.81
# -----------------------------------------------------
# cc_onco775.ann		0.812
# -----------------------------------------------------
# cc_onco781.ann		0.667
# -----------------------------------------------------
# cc_onco782.ann		1.0
# -----------------------------------------------------
# cc_onco785.ann		0.882
# -----------------------------------------------------
# cc_onco793.ann		0.8
# -----------------------------------------------------
# cc_onco801.ann		0.947
# -----------------------------------------------------
# cc_onco805.ann		1.0
# -----------------------------------------------------
# cc_onco809.ann		0.875
# -----------------------------------------------------
# cc_onco810.ann		0.571
# -----------------------------------------------------
# cc_onco811.ann		0.938
# -----------------------------------------------------
# cc_onco812.ann		1.0
# -----------------------------------------------------
# cc_onco822.ann		1.0
# -----------------------------------------------------
# cc_onco827.ann		0.857
# -----------------------------------------------------
# cc_onco831.ann		1.0
# -----------------------------------------------------
# cc_onco834.ann		0.857
# -----------------------------------------------------
# cc_onco838.ann		0.867
# -----------------------------------------------------
# cc_onco842.ann		1.0
# -----------------------------------------------------
# cc_onco843.ann		0.846
# -----------------------------------------------------
# cc_onco855.ann		0.846
# -----------------------------------------------------
# cc_onco867.ann		0.917
# -----------------------------------------------------
# cc_onco877.ann		0.857
# -----------------------------------------------------
# cc_onco880.ann		1.0
# -----------------------------------------------------
# cc_onco881.ann		1.0
# -----------------------------------------------------
# cc_onco887.ann		0.833
# -----------------------------------------------------
# cc_onco89.ann		0.778
# -----------------------------------------------------
# cc_onco899.ann		1.0
# -----------------------------------------------------
# cc_onco9.ann		0.875
# -----------------------------------------------------
# cc_onco901.ann		1.0
# -----------------------------------------------------
# cc_onco902.ann		0.833
# -----------------------------------------------------
# cc_onco926.ann		0.75
# -----------------------------------------------------
# cc_onco928.ann		0.9
# -----------------------------------------------------
# cc_onco938.ann		0.958
# -----------------------------------------------------
# cc_onco94.ann		0.778
# -----------------------------------------------------
# cc_onco941.ann		0.818
# -----------------------------------------------------
# cc_onco943.ann		0.75
# -----------------------------------------------------
# cc_onco950.ann		1.0
# -----------------------------------------------------
# cc_onco953.ann		0.889
# -----------------------------------------------------
# cc_onco956.ann		0.667
# -----------------------------------------------------
# cc_onco958.ann		1.0
# -----------------------------------------------------
# cc_onco960.ann		0.846
# -----------------------------------------------------
# cc_onco964.ann		1.0
# -----------------------------------------------------
# cc_onco975.ann		0.929
# -----------------------------------------------------
# cc_onco977.ann		0.889
# -----------------------------------------------------
# cc_onco978.ann		1.0
# -----------------------------------------------------
#
# -----------------------------------------------------
# Clinical case name			F-score
# -----------------------------------------------------
# cc_onco1006.ann		1.0
# -----------------------------------------------------
# cc_onco1023.ann		0.938
# -----------------------------------------------------
# cc_onco1027.ann		0.5
# -----------------------------------------------------
# cc_onco1038.ann		0.851
# -----------------------------------------------------
# cc_onco104.ann		0.88
# -----------------------------------------------------
# cc_onco1040.ann		0.909
# -----------------------------------------------------
# cc_onco1044.ann		0.941
# -----------------------------------------------------
# cc_onco1046.ann		0.769
# -----------------------------------------------------
# cc_onco1051.ann		0.786
# -----------------------------------------------------
# cc_onco1056.ann		1.0
# -----------------------------------------------------
# cc_onco1057.ann		0.867
# -----------------------------------------------------
# cc_onco1059.ann		0.822
# -----------------------------------------------------
# cc_onco1064.ann		0.857
# -----------------------------------------------------
# cc_onco1065.ann		0.533
# -----------------------------------------------------
# cc_onco1066.ann		0.947
# -----------------------------------------------------
# cc_onco1075.ann		1.0
# -----------------------------------------------------
# cc_onco1078.ann		0.833
# -----------------------------------------------------
# cc_onco1080.ann		1.0
# -----------------------------------------------------
# cc_onco1083.ann		1.0
# -----------------------------------------------------
# cc_onco1084.ann		0.667
# -----------------------------------------------------
# cc_onco1085.ann		1.0
# -----------------------------------------------------
# cc_onco1092.ann		1.0
# -----------------------------------------------------
# cc_onco1096.ann		0.968
# -----------------------------------------------------
# cc_onco1108.ann		1.0
# -----------------------------------------------------
# cc_onco1110.ann		1.0
# -----------------------------------------------------
# cc_onco1113.ann		0.75
# -----------------------------------------------------
# cc_onco1116.ann		1.0
# -----------------------------------------------------
# cc_onco112.ann		1.0
# -----------------------------------------------------
# cc_onco1120.ann		1.0
# -----------------------------------------------------
# cc_onco1125.ann		1.0
# -----------------------------------------------------
# cc_onco1126.ann		0.75
# -----------------------------------------------------
# ...
# -----------------------------------------------------
# cc_onco1352.ann		0.9
# -----------------------------------------------------
# cc_onco1357.ann		0.571
# -----------------------------------------------------
# cc_onco136.ann		0.615
# -----------------------------------------------------
# cc_onco1360.ann		0.842
# -----------------------------------------------------
# cc_onco1362.ann		1.0
# -----------------------------------------------------
# cc_onco1364.ann		0.778
# -----------------------------------------------------
# cc_onco1366.ann		0.824
# -----------------------------------------------------
# cc_onco1367.ann		0.909
# -----------------------------------------------------
# cc_onco1370.ann		0.909
# -----------------------------------------------------
# cc_onco1378.ann		1.0
# -----------------------------------------------------
# cc_onco1379.ann		1.0
# -----------------------------------------------------
# cc_onco1381.ann		0.833
# -----------------------------------------------------
# cc_onco1385.ann		0.8
# -----------------------------------------------------
# cc_onco139.ann		1.0
# -----------------------------------------------------
# cc_onco1398.ann		0.818
# -----------------------------------------------------
# cc_onco1401.ann		0.857
# -----------------------------------------------------
# cc_onco1403.ann		0.96
# -----------------------------------------------------
# cc_onco1406.ann		1.0
# -----------------------------------------------------
# cc_onco1410.ann		0.667
# -----------------------------------------------------
# cc_onco1411.ann		0.818
# -----------------------------------------------------
# cc_onco1416.ann		0.87
# -----------------------------------------------------
# cc_onco1423.ann		1.0
# -----------------------------------------------------
# cc_onco1426.ann		0.8
# -----------------------------------------------------
# cc_onco1430.ann		0.667
# -----------------------------------------------------
# cc_onco1433.ann		1.0
# -----------------------------------------------------
# cc_onco1434.ann		1.0
# -----------------------------------------------------
# cc_onco1439.ann		0.933
# -----------------------------------------------------
# cc_onco1446.ann		1.0
# -----------------------------------------------------
# cc_onco1450.ann		0.8
# -----------------------------------------------------
# cc_onco1452.ann		1.0
# -----------------------------------------------------
# cc_onco1453.ann		0.9
# -----------------------------------------------------
# cc_onco1454.ann		1.0
# -----------------------------------------------------
# cc_onco1455.ann		1.0
# -----------------------------------------------------
# cc_onco1458.ann		1.0
# -----------------------------------------------------
# cc_onco1460.ann		0.696
# -----------------------------------------------------
# cc_onco1466.ann		0.971
# -----------------------------------------------------
# cc_onco1469.ann		0.897
# -----------------------------------------------------
# cc_onco1472.ann		0.25
# -----------------------------------------------------
# cc_onco1473.ann		0.792
# -----------------------------------------------------
# cc_onco1479.ann		0.72
# -----------------------------------------------------
# cc_onco1480.ann		0.741
# -----------------------------------------------------
# cc_onco1483.ann		0.87
# -----------------------------------------------------
# cc_onco1485.ann		0.667
# -----------------------------------------------------
# cc_onco1489.ann		1.0
# -----------------------------------------------------
# cc_onco1491.ann		0.667
# -----------------------------------------------------
# cc_onco1496.ann		0.903
# -----------------------------------------------------
# cc_onco1499.ann		1.0
# -----------------------------------------------------
# cc_onco151.ann		0.889
# -----------------------------------------------------
# cc_onco172.ann		0.944
# -----------------------------------------------------
# cc_onco178.ann		1.0
# -----------------------------------------------------
# cc_onco179.ann		0.896
# -----------------------------------------------------
# cc_onco190.ann		0.929
# -----------------------------------------------------
# cc_onco191.ann		1.0
# -----------------------------------------------------
# cc_onco221.ann		0.923
# -----------------------------------------------------
# cc_onco228.ann		1.0
# -----------------------------------------------------
# cc_onco238.ann		0.914
# -----------------------------------------------------
# cc_onco24.ann		0.694
# -----------------------------------------------------
# cc_onco240.ann		1.0
# -----------------------------------------------------
# cc_onco241.ann		0.846
# -----------------------------------------------------
# cc_onco242.ann		0.952
# -----------------------------------------------------
# cc_onco248.ann		1.0
# -----------------------------------------------------
# cc_onco260.ann		1.0
# -----------------------------------------------------
# cc_onco268.ann		1.0
# -----------------------------------------------------
# cc_onco270.ann		0.95
# -----------------------------------------------------
# cc_onco281.ann		0.966
# -----------------------------------------------------
# cc_onco283.ann		0.839
# -----------------------------------------------------
# cc_onco285.ann		1.0
# -----------------------------------------------------
# cc_onco287.ann		0.87
# -----------------------------------------------------
# cc_onco290.ann		1.0
# -----------------------------------------------------
# cc_onco292.ann		0.929
# -----------------------------------------------------
# cc_onco294.ann		1.0
# -----------------------------------------------------
# cc_onco304.ann		0.842
# -----------------------------------------------------
# cc_onco305.ann		0.898
# -----------------------------------------------------
# cc_onco323.ann		0.889
# -----------------------------------------------------
# cc_onco329.ann		0.889
# -----------------------------------------------------
# cc_onco33.ann		0.87
# -----------------------------------------------------
# cc_onco332.ann		0.95
# -----------------------------------------------------
# cc_onco333.ann		1.0
# -----------------------------------------------------
# cc_onco339.ann		0.889
# -----------------------------------------------------
# cc_onco349.ann		0.923
# -----------------------------------------------------
# cc_onco359.ann		0.824
# -----------------------------------------------------
# cc_onco365.ann		0.5
# -----------------------------------------------------
# cc_onco373.ann		0.833
# -----------------------------------------------------
# cc_onco383.ann		1.0
# -----------------------------------------------------
# cc_onco389.ann		0.812
# -----------------------------------------------------
# cc_onco397.ann		0.889
# -----------------------------------------------------
# cc_onco399.ann		0.909
# -----------------------------------------------------
# cc_onco410.ann		0.909
# -----------------------------------------------------
# cc_onco414.ann		1.0
# -----------------------------------------------------
# cc_onco421.ann		1.0
# -----------------------------------------------------
# cc_onco431.ann		0.898
# -----------------------------------------------------
# cc_onco441.ann		0.889
# -----------------------------------------------------
# cc_onco447.ann		1.0
# -----------------------------------------------------
# cc_onco448.ann		0.72
# -----------------------------------------------------
# cc_onco451.ann		0.96
# -----------------------------------------------------
# cc_onco454.ann		1.0
# -----------------------------------------------------
# cc_onco456.ann		0.963
# -----------------------------------------------------
# cc_onco465.ann		0.912
# -----------------------------------------------------
# cc_onco47.ann		0.898
# -----------------------------------------------------
# cc_onco471.ann		1.0
# -----------------------------------------------------
# cc_onco476.ann		0.947
# -----------------------------------------------------
# cc_onco484.ann		0.756
# -----------------------------------------------------
# cc_onco487.ann		0.667
# -----------------------------------------------------
# cc_onco494.ann		0.857
# -----------------------------------------------------
# cc_onco495.ann		0.941
# -----------------------------------------------------
# cc_onco497.ann		0.5
# -----------------------------------------------------
# cc_onco505.ann		0.875
# -----------------------------------------------------
# cc_onco508.ann		1.0
# -----------------------------------------------------
# cc_onco511.ann		0.8
# -----------------------------------------------------
# cc_onco512.ann		1.0
# -----------------------------------------------------
# cc_onco514.ann		0.929
# -----------------------------------------------------
# cc_onco515.ann		0.889
# -----------------------------------------------------
# cc_onco52.ann		0.8
# -----------------------------------------------------
# cc_onco524.ann		0.8
# -----------------------------------------------------
# cc_onco526.ann		1.0
# -----------------------------------------------------
# cc_onco527.ann		0.882
# -----------------------------------------------------
# cc_onco53.ann		0.903
# -----------------------------------------------------
# cc_onco532.ann		0.667
# -----------------------------------------------------
# cc_onco539.ann		1.0
# -----------------------------------------------------
# cc_onco540.ann		1.0
# -----------------------------------------------------
# cc_onco546.ann		0.857
# -----------------------------------------------------
# cc_onco548.ann		0.833
# -----------------------------------------------------
# cc_onco549.ann		0.898
# -----------------------------------------------------
# cc_onco561.ann		0.8
# -----------------------------------------------------
# cc_onco564.ann		0.743
# -----------------------------------------------------
# cc_onco574.ann		0.923
# -----------------------------------------------------
# cc_onco584.ann		0.723
# -----------------------------------------------------
# cc_onco589.ann		0.947
# -----------------------------------------------------
# cc_onco600.ann		0.833
# -----------------------------------------------------
# cc_onco601.ann		0.923
# -----------------------------------------------------
# cc_onco604.ann		0.667
# -----------------------------------------------------
# cc_onco607.ann		1.0
# -----------------------------------------------------
# cc_onco611.ann		0.963
# -----------------------------------------------------
# cc_onco621.ann		0.957
# -----------------------------------------------------
# cc_onco624.ann		0.87
# -----------------------------------------------------
# cc_onco627.ann		0.839
# -----------------------------------------------------
# cc_onco629.ann		0.786
# -----------------------------------------------------
# cc_onco632.ann		0.625
# -----------------------------------------------------
# cc_onco637.ann		1.0
# -----------------------------------------------------
# cc_onco641.ann		0.898
# -----------------------------------------------------
# cc_onco651.ann		0.583
# -----------------------------------------------------
# cc_onco656.ann		0.955
# -----------------------------------------------------
# cc_onco659.ann		1.0
# -----------------------------------------------------
# cc_onco660.ann		0.727
# -----------------------------------------------------
# cc_onco661.ann		0.857
# -----------------------------------------------------
# cc_onco664.ann		0.923
# -----------------------------------------------------
# cc_onco680.ann		0.8
# -----------------------------------------------------
# cc_onco683.ann		0.808
# -----------------------------------------------------
# cc_onco69.ann		0.966
# -----------------------------------------------------
# cc_onco693.ann		0.941
# -----------------------------------------------------
# cc_onco701.ann		1.0
# -----------------------------------------------------
# cc_onco712.ann		0.884
# -----------------------------------------------------
# cc_onco715.ann		1.0
# -----------------------------------------------------
# cc_onco72.ann		0.952
# -----------------------------------------------------
# cc_onco722.ann		1.0
# -----------------------------------------------------
# cc_onco742.ann		0.917
# -----------------------------------------------------
# cc_onco748.ann		0.933
# -----------------------------------------------------
# cc_onco749.ann		1.0
# -----------------------------------------------------
# cc_onco75.ann		1.0
# -----------------------------------------------------
# cc_onco750.ann		1.0
# -----------------------------------------------------
# cc_onco756.ann		1.0
# -----------------------------------------------------
# cc_onco770.ann		0.877
# -----------------------------------------------------
# cc_onco772.ann		0.81
# -----------------------------------------------------
# cc_onco775.ann		0.839
# -----------------------------------------------------
# cc_onco781.ann		0.727
# -----------------------------------------------------
# cc_onco782.ann		1.0
# -----------------------------------------------------
# cc_onco785.ann		0.882
# -----------------------------------------------------
# cc_onco793.ann		0.5
# -----------------------------------------------------
# cc_onco801.ann		0.947
# -----------------------------------------------------
# cc_onco805.ann		1.0
# -----------------------------------------------------
# cc_onco809.ann		0.824
# -----------------------------------------------------
# cc_onco810.ann		0.667
# -----------------------------------------------------
# cc_onco811.ann		0.938
# -----------------------------------------------------
# cc_onco812.ann		1.0
# -----------------------------------------------------
# cc_onco822.ann		1.0
# -----------------------------------------------------
# cc_onco827.ann		0.923
# -----------------------------------------------------
# cc_onco831.ann		0.96
# -----------------------------------------------------
# cc_onco834.ann		0.706
# -----------------------------------------------------
# cc_onco838.ann		0.867
# -----------------------------------------------------
# cc_onco842.ann		1.0
# -----------------------------------------------------
# cc_onco843.ann		0.83
# -----------------------------------------------------
# cc_onco855.ann		0.815
# -----------------------------------------------------
# cc_onco867.ann		0.815
# -----------------------------------------------------
# cc_onco877.ann		0.842
# -----------------------------------------------------
# cc_onco880.ann		1.0
# -----------------------------------------------------
# cc_onco881.ann		0.875
# -----------------------------------------------------
# cc_onco887.ann		0.909
# -----------------------------------------------------
# cc_onco89.ann		0.875
# -----------------------------------------------------
# cc_onco899.ann		1.0
# -----------------------------------------------------
# cc_onco9.ann		0.875
# -----------------------------------------------------
# cc_onco901.ann		0.727
# -----------------------------------------------------
# cc_onco902.ann		0.833
# -----------------------------------------------------
# cc_onco926.ann		0.8
# -----------------------------------------------------
# cc_onco928.ann		0.857
# -----------------------------------------------------
# cc_onco938.ann		0.958
# -----------------------------------------------------
# cc_onco94.ann		0.875
# -----------------------------------------------------
# cc_onco941.ann		0.75
# -----------------------------------------------------
# cc_onco943.ann		0.706
# -----------------------------------------------------
# cc_onco950.ann		1.0
# -----------------------------------------------------
# cc_onco953.ann		0.941
# -----------------------------------------------------
# cc_onco956.ann		0.8
# -----------------------------------------------------
# cc_onco958.ann		0.963
# -----------------------------------------------------
# cc_onco960.ann		0.733
# -----------------------------------------------------
# cc_onco964.ann		1.0
# -----------------------------------------------------
# cc_onco975.ann		0.929
# -----------------------------------------------------
# cc_onco977.ann		0.889
# -----------------------------------------------------
# cc_onco978.ann		1.0
# -----------------------------------------------------
#
# -----------------------------------------------------
# Micro-average metrics
# -----------------------------------------------------
#
# Micro-average precision = 0.893
#
#
# Micro-average recall = 0.887
#
#
# Micro-average F-score = 0.89
#
# ./ens_test_preds/|0.893|0.887|0.89
# CPU times: user 15 ms, sys: 16.2 ms, total: 31.3 ms
# Wall time: 1.14 s
